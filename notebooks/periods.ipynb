# %%
import pandas as pd
from datetime import datetime, timedelta

# %%
df = pd.read_excel('../data/Online Retail.xlsx')
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %%
last_date = df['InvoiceDate'].max()
last_date
# Out:
# Timestamp('2011-12-09 12:50:00')

# %%
first_date = last_date - timedelta(7)
first_date
# Out:
# Timestamp('2011-12-02 12:50:00')

# %%
df.loc[df['InvoiceDate'].between(first_date, last_date)]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 520149    580272     84347  ROTATING SILVER ANGELS T-LIGHT HLDR        10
# 520150    580272     21265         PINK GOOSE FEATHER TREE 60CM         4
# 520151    580272     21175        GIN AND TONIC DIET METAL SIGN         2
# 520152    580272     85150        LADIES & GENTLEMEN METAL SIGN         2
# 520153    580272     20914  SET/5 RED RETROSPOT LID GLASS BOWLS         3
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...
